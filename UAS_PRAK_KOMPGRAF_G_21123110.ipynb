# %%
# import module
import pandas as pd
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1079af74-20c6-4223-a386-3fff78dc174b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1079af74-20c6-4223-a386-3fff78dc174b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('stock.csv')
df.head()
# Out:
#                                                                                            Stock Name;Symbol;Shares;Purchase Price;Cost Basis;Current Price;Market Value;Gain/Loss;Dividend/share;Annual Yield;;;
# Apple;AAPL;100;$90                     00 ;$9.000 ;$144 13;$14.413 27 ;$14.269 14 ;$2 28;1                                             58%;;;
# Microsoft;MSFT;200;$32                 00 ;$6.400 ;$65  57;$13.114 14 ;$13.048 57 ;$1 56;2                                             38%;;;
# Salesforce;CRM;150;$25                 00 ;$3.750 ;$82  57;$12.385 50 ;$12.302 93 ;$0 00;0                                             00%;;;
# Oracle;ORCL;125;$50                    00 ;$12.500 ;$44 56;$11.138 75 ;$11.094 20 ;$0 64;1                                             44%;;;
# Hewlett Packard Enterprise;HPE;500;$18 00 ;$9.000 ;$17  69;$8.842  50 ;$8.824  82 ;$0 26;1                                             47%;;;

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# Load data from text
data = """Stock Name;Symbol;Shares;Purchase Price;Cost Basis;Current Price;Market Value;Gain/Loss;Dividend/share;Annual Yield
Apple;AAPL;100;$90.00;$9,000.00;$144.13;$14,413.27;$14,269.14;$2.28;1.58%
Microsoft;MSFT;200;$32.00;$6,400.00;$65.57;$13,114.14;$13,048.57;$2.24;2.38%
Salesforce;CRM;50;$40.00;$2,000.00;$47.48;$2,374.00;$2,352.00;$0.54;1.14%
Oracle;ORCL;200;$35.00;$7,000.00;$44.56;$8,912.00;$8,822.00;$0.36;0.81%
Hewlett Packard Enterprise;HPE;500;$18.00;$9,000.00;$14.92;$7,460.00;$7,521.00;$0.30;2.01%
Alphabet;GOOG;100;$225.00;$22,500.00;$223.33;$22,333.00;$22,376.00;$0.00;0.00%
Intel;INTC;150;$30.00;$4,500.00;$31.03;$4,654.50;$4,522.00;$1.02;3.29%
Cisco;CSCO;225;$22.00;$4,950.00;$23.12;$5,202.00;$5,199.00;$0.72;3.11%
Qualcomm;QCOM;185;$65.00;$12,025.00;$88.33;$16,350.25;$16,495.00;$2.48;2.81%
Amazon;AMZN;10;$410.00;$4,100.00;$820.00;$8,200.00;$8,357.00;$0.00;0.00%
Redhat;RHT;75;$65.00;$4,875.00;$95.00;$7,125.00;$7,242.00;$0.00;0.00%
Facebook;FB;100;$27.00;$2,700.00;$46.88;$4,688.00;$4,615.00;$0.00;0.00%
Twitter;TWTR;500;$45.00;$22,500.00;$14.61;$7,302.50;$7,287.94;$0.00;0.00%
"""

# Buat pandas DataFrame dari teks
df = pd.read_csv(io.StringIO(data), sep=';')

# Hapus tanda dolar, koma, dan tanda persen dan ubah menjadi float
df['Purchase Price'] = df['Purchase Price'].str.replace('[\$,]', '', regex=True).astype(float)
df['Current Price'] = df['Current Price'].str.replace('[\$,]', '', regex=True).astype(float)
df['Gain/Loss'] = df['Gain/Loss'].str.replace('[\$,]', '', regex=True).astype(float)
df['Annual Yield'] = df['Annual Yield'].str.replace('%', '').astype(float)

# Siapkan gambar dan subplotnya
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot histogram untuk Purchase Price, Current Price, and Gain/Loss dengan warna berbeda
sns.histplot(df['Purchase Price'], ax=axes[0], color='blue')
axes[0].set_title('Purchase Price Distribution')

sns.histplot(df['Current Price'], ax=axes[1], color='green')
axes[1].set_title('Current Price Distribution')

sns.histplot(df['Gain/Loss'], ax=axes[2], color='red')
axes[2].set_title('Gain/Loss Distribution')

# Sesuaikan jarak antar subplots
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# Load data from the provided string
data = """Stock Name;Symbol;Shares;Purchase Price;Cost Basis;Current Price;Market Value;Gain/Loss;Dividend/share;Annual Yield
Apple;AAPL;100;$90.00;$9,000.00;$144.13;$14,413.27;$14,269.14;$2.28;1.58%
Microsoft;MSFT;200;$32.00;$6,400.00;$65.57;$13,114.14;$13,048.57;$2.24;2.38%
Salesforce;CRM;50;$40.00;$2,000.00;$47.48;$2,374.00;$2,352.00;$0.54;1.14%
Oracle;ORCL;200;$35.00;$7,000.00;$44.56;$8,912.00;$8,822.00;$0.36;0.81%
Hewlett Packard Enterprise;HPE;500;$18.00;$9,000.00;$14.92;$7,460.00;$7,521.00;$0.30;2.01%
Alphabet;GOOG;100;$225.00;$22,500.00;$223.33;$22,333.00;$22,376.00;$0.00;0.00%
Intel;INTC;150;$30.00;$4,500.00;$31.03;$4,654.50;$4,522.00;$1.02;3.29%
Cisco;CSCO;225;$22.00;$4,950.00;$23.12;$5,202.00;$5,199.00;$0.72;3.11%
Qualcomm;QCOM;185;$65.00;$12,025.00;$88.33;$16,350.25;$16,495.00;$2.48;2.81%
Amazon;AMZN;10;$410.00;$4,100.00;$820.00;$8,200.00;$8,357.00;$0.00;0.00%
Redhat;RHT;75;$65.00;$4,875.00;$95.00;$7,125.00;$7,242.00;$0.00;0.00%
Facebook;FB;100;$27.00;$2,700.00;$46.88;$4,688.00;$4,615.00;$0.00;0.00%
Twitter;TWTR;500;$45.00;$22,500.00;$14.61;$7,302.50;$7,287.94;$0.00;0.00%"""

# Create a DataFrame from the data
df = pd.read_csv(io.StringIO(data), sep=";")

# Remove dollar signs, commas, and percent signs and convert to appropriate types
df['Purchase Price'] = df['Purchase Price'].str.replace('[\$,]', '', regex=True).astype(float)
df['Cost Basis'] = df['Cost Basis'].str.replace('[\$,]', '', regex=True).astype(float)
df['Current Price'] = df['Current Price'].str.replace('[\$,]', '', regex=True).astype(float)
df['Market Value'] = df['Market Value'].str.replace('[\$,]', '', regex=True).astype(float)
df['Gain/Loss'] = df['Gain/Loss'].str.replace('[\$,]', '', regex=True).astype(float)
df['Dividend/share'] = pd.to_numeric(df['Dividend/share'], errors='coerce')
df['Annual Yield'] = df['Annual Yield'].str.replace('%', '').astype(float)

# Sort and get the top 5 stocks by 'Dividend/share'
top_dividends = df.nlargest(5, 'Dividend/share')[['Stock Name', 'Symbol', 'Dividend/share']]
print("Top 5 Stocks by Dividend/share:")
print(top_dividends)
# Out:
# Top 5 Stocks by Dividend/share:
#                    Stock Name Symbol  Dividend/share
# 0                       Apple   AAPL             NaN
# 1                   Microsoft   MSFT             NaN
# 2                  Salesforce    CRM             NaN
# 3                      Oracle   ORCL             NaN
# 4  Hewlett Packard Enterprise    HPE             NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# Data
data = """Stock Name;Symbol;Shares;Purchase Price;Cost Basis;Current Price;Market Value;Gain/Loss;Dividend/share;Annual Yield
Apple;AAPL;100;$90.00;$9,000.00;$144.13;$14,413.27;$14,269.14;$2.28;1.58%
Microsoft;MSFT;200;$32.00;$6,400.00;$65.57;$13,114.14;$13,048.57;$2.24;2.38%
Salesforce;CRM;50;$40.00;$2,000.00;$47.48;$2,374.00;$2,352.00;$0.54;1.14%
Oracle;ORCL;200;$35.00;$7,000.00;$44.56;$8,912.00;$8,822.00;$0.36;0.81%
Hewlett Packard Enterprise;HPE;500;$18.00;$9,000.00;$14.92;$7,460.00;$7,521.00;$0.30;2.01%
Alphabet;GOOG;100;$225.00;$22,500.00;$223.33;$22,333.00;$22,376.00;$0.00;0.00%
Intel;INTC;150;$30.00;$4,500.00;$31.03;$4,654.50;$4,522.00;$1.02;3.29%
Cisco;CSCO;225;$22.00;$4,950.00;$23.12;$5,202.00;$5,199.00;$0.72;3.11%
Qualcomm;QCOM;185;$65.00;$12,025.00;$88.33;$16,350.25;$16,495.00;$2.48;2.81%
Amazon;AMZN;10;$410.00;$4,100.00;$820.00;$8,200.00;$8,357.00;$0.00;0.00%
Redhat;RHT;75;$65.00;$4,875.00;$95.00;$7,125.00;$7,242.00;$0.00;0.00%
Facebook;FB;100;$27.00;$2,700.00;$46.88;$4,688.00;$4,615.00;$0.00;0.00%
Twitter;TWTR;500;$45.00;$22,500.00;$14.61;$7,302.50;$7,287.94;$0.00;0.00%"""

# Buat dataframe dari data
df = pd.read_csv(io.StringIO(data), sep=";")

# Konversi kolom 'Market Value' ke numerik
df['Market Value'] = df['Market Value'].str.replace('[\$,]', '', regex=True).astype(float)

# Urutkan berdasarkan 'Market Value' secara descending
df_sorted = df.sort_values(by='Market Value', ascending=False)

# Ambil 5 saham dengan 'Market Value' tertinggi
top_5 = df_sorted.head(5)

# Visualisasi data menggunakan bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Stock Name', y='Market Value', data=top_5, palette='viridis')
plt.title('Top 5 Stocks by Market Value')
plt.xlabel('Stock Name')
plt.ylabel('Market Value')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-30-0d896d783268>:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Stock Name', y='Market Value', data=top_5, palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# Load data from the text
data = """Stock Name;Symbol;Shares;Purchase Price;Cost Basis;Current Price;Market Value;Gain/Loss;Dividend/share;Annual Yield
Apple;AAPL;100;$90.00;$9,000.00;$144.13;$14,413.27;$14,269.14;$2.28;1.58%
Microsoft;MSFT;200;$32.00;$6,400.00;$65.57;$13,114.14;$13,048.57;$2.24;2.38%
Salesforce;CRM;50;$40.00;$2,000.00;$47.48;$2,374.00;$2,352.00;$0.54;1.14%
Oracle;ORCL;200;$35.00;$7,000.00;$44.56;$8,912.00;$8,822.00;$0.36;0.81%
Hewlett Packard Enterprise;HPE;500;$18.00;$9,000.00;$14.92;$7,460.00;$7,521.00;$0.30;2.01%
Alphabet;GOOG;100;$225.00;$22,500.00;$223.33;$22,333.00;$22,376.00;$0.00;0.00%
Intel;INTC;150;$30.00;$4,500.00;$31.03;$4,654.50;$4,522.00;$1.02;3.29%
Cisco;CSCO;225;$22.00;$4,950.00;$23.12;$5,202.00;$5,199.00;$0.72;3.11%
Qualcomm;QCOM;185;$65.00;$12,025.00;$88.33;$16,350.25;$16,495.00;$2.48;2.81%
Amazon;AMZN;10;$410.00;$4,100.00;$820.00;$8,200.00;$8,357.00;$0.00;0.00%
Redhat;RHT;75;$65.00;$4,875.00;$95.00;$7,125.00;$7,242.00;$0.00;0.00%
Facebook;FB;100;$27.00;$2,700.00;$46.88;$4,688.00;$4,615.00;$0.00;0.00%
Twitter;TWTR;500;$45.00;$22,500.00;$14.61;$7,302.50;$7,287.94;$0.00;0.00%
"""

# Create a Pandas DataFrame from the text
df = pd.read_csv(io.StringIO(data), sep=";")

# Convert 'Annual Yield' to numeric
df['Annual Yield'] = df['Annual Yield'].str.rstrip('%').astype('float') / 100

# Sort by Annual Yield in descending order and get the top 7
top_7_annual_yield = df.sort_values(by='Annual Yield', ascending=False).head(7)

# Visualize with Seaborn
plt.figure(figsize=(10, 6))

# Create a color palette based on the values of 'Annual Yield'
palette = sns.color_palette("viridis", len(top_7_annual_yield))

# Create the bar plot with the custom palette
sns.barplot(x='Annual Yield', y='Stock Name', data=top_7_annual_yield, palette=palette, orient='h')
plt.title('Top 7 Stocks with Highest Annual Yield')
plt.xlabel('Annual Yield (%)')
plt.ylabel('Stock Name')
plt.show()
# Out:
# <ipython-input-32-d9ed8e7c4555>:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Annual Yield', y='Stock Name', data=top_7_annual_yield, palette=palette, orient='h')
